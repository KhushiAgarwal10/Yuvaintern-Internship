# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
df=pd.read_csv('cleaned_crop_dataset.csv')

# %%
df.head()
# Out:
#    Unnamed: 0     Area         Item  Year  hg/ha_yield  \
# 0           0  Albania        Maize  1990     0.072927
# 1           1  Albania     Potatoes  1990     0.132872
# 2           2  Albania  Rice, paddy  1990     0.046439
# 3           3  Albania      Sorghum  1990     0.024832
# 4           4  Albania     Soybeans  1990     0.013862
#
#    average_rain_fall_mm_per_year  pesticides_tonnes  avg_temp
# 0                       0.449671           0.000329  0.513458
# 1                       0.449671           0.000329  0.513458
# 2                       0.449671           0.000329  0.513458
# 3                       0.449671           0.000329  0.513458
# 4                       0.449671           0.000329  0.513458

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 28242 entries, 0 to 28241
# Data columns (total 8 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Unnamed: 0                     28242 non-null  int64
#  1   Area                           28242 non-null  str
#  2   Item                           28242 non-null  str
#  3   Year                           28242 non-null  int64
#  4   hg/ha_yield                    28242 non-null  float64
#  5   average_rain_fall_mm_per_year  28242 non-null  float64
#  6   pesticides_tonnes              28242 non-null  float64
#  7   avg_temp                       28242 non-null  float64
# dtypes: float64(4), int64(2), str(2)
# memory usage: 1.7 MB

# %%
df.describe()
# Out:
#          Unnamed: 0          Year   hg/ha_yield  \
# count  28242.000000  28242.000000  28242.000000
# mean   14120.500000   2001.544296      0.153588
# std     8152.907488      7.051905      0.169452
# min        0.000000   1990.000000      0.000000
# 25%     7060.250000   1995.000000      0.039631
# 50%    14120.500000   2001.000000      0.076282
# 75%    21180.750000   2008.000000      0.208685
# max    28241.000000   2013.000000      1.000000
#
#        average_rain_fall_mm_per_year  pesticides_tonnes      avg_temp
# count                   28242.000000       28242.000000  28242.000000
# mean                        0.344326           0.100813      0.655626
# std                         0.222581           0.163030      0.215061
# min                         0.000000           0.000000      0.000000
# 25%                         0.169959           0.004628      0.524787
# 50%                         0.323612           0.047663      0.688586
# 75%                         0.507056           0.132384      0.841567
# max                         1.000000           1.000000      1.000000

# %% [markdown]
# Check Correlation

# %%
df.corr(numeric_only=True)
# Out:
#                                Unnamed: 0      Year  hg/ha_yield  \
# Unnamed: 0                       1.000000  0.043850     0.013395
# Year                             0.043850  1.000000     0.091630
# hg/ha_yield                      0.013395  0.091630     1.000000
# average_rain_fall_mm_per_year   -0.228755 -0.003798     0.000962
# pesticides_tonnes               -0.316017  0.140930     0.064085
# avg_temp                        -0.051584  0.014409    -0.114777
#
#                                average_rain_fall_mm_per_year  \
# Unnamed: 0                                         -0.228755
# Year                                               -0.003798
# hg/ha_yield                                         0.000962
# average_rain_fall_mm_per_year                       1.000000
# pesticides_tonnes                                   0.180984
# avg_temp                                            0.313040
#
#                                pesticides_tonnes  avg_temp
# Unnamed: 0                             -0.316017 -0.051584
# Year                                    0.140930  0.014409
# hg/ha_yield                             0.064085 -0.114777
# average_rain_fall_mm_per_year           0.180984  0.313040
# pesticides_tonnes                       1.000000  0.030946
# avg_temp                                0.030946  1.000000

# %% [markdown]
# Correlation Heatmap

# %%
plt.figure(figsize=(10,6))
sns.heatmap(df.corr(numeric_only=True), annot=True, cmap='coolwarm')
plt.title("Correlation Heatmap")
plt.show()

# %% [markdown]
# Distribution Analysis  - Histogram

# %%
df.hist(figsize=(12,10))
plt.show()

# %% [markdown]
# Outlier Analysis - Boxplot

# %%
sns.boxplot(df['hg/ha_yield'])
plt.title("Crop Yield Boxplot")
plt.show()

# %% [markdown]
# Relationship Analysis - Scatter Plot

# %%
sns.scatterplot(x='avg_temp', y='hg/ha_yield', data=df)
plt.title("Temperature vs Crop Yield")
plt.show()

# %% [markdown]
# Pairplot Visualization

# %%
sns.pairplot(df.select_dtypes(include=np.number))
plt.show()
